# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from pprint import pprint
import time

from ipywidgets.embed import embed_minimal_html

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# Load the CSV
Csv_path = "../001_WeatherPy/002-Output/Weather_Data_DF.csv"
Weather_Data_DF = pd.read_csv(Csv_path)
Weather_Data_DF.dropna()
Weather_Data_DF.head()
# Out:
#             City  City_ID Country  Latitude  Longitude  Temperature  Humidity  \
# 0           Chui  3443061      UY  -33.6971   -53.4616       284.38        96
# 1    New Norfolk  2155415      AU  -42.7826   147.0587       280.81        70
# 2  Sioux Lookout  6148373      CA   50.1001   -91.9170       294.80        60
# 3       Manthani  1263610      IN   18.6500    79.6667       296.89        97
# 4     Codrington  2171099      AU  -38.2667   141.9667       284.01        84
#
#    Max Temp  Wind Speed  Cloudiness
# 0    284.38        1.40          86
# 1    281.87        0.45          76
# 2    294.80        4.99           1
# 3    296.89        3.14         100
# 4    284.01        2.68         100

# %%
# Create a list containing coordinates
coordinates = Weather_Data_DF[["Latitude", "Longitude"]].astype(float)
humidity = Weather_Data_DF["Humidity"].astype(float)

# %%
# Customize the size of the figure
figure_layout = {
    'width': '780px',
    'height': '700px',
    'border': '1px solid black',
    'padding': '10px',
    'margin': '0 auto 0 auto'
}


# select a map type
fig = gmaps.figure(layout=figure_layout, 
                   map_type="HYBRID"
                  )


# Assign the marker layer to a variable
#markers = gmaps.marker_layer(coordinates)
markers = gmaps.heatmap_layer(coordinates)


# Create heat layer
heat_layer = gmaps.heatmap_layer(coordinates, 
                                 weights=humidity, 
                                 dissipating=False, 
                                 max_intensity=100,
                                 point_radius=1
                                )

# Add layer
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='700px', margin='0 auto 0 auto', padding='10px', w…

# %%
embed_minimal_html('./002-Output/map_1.html', views=[fig])

# %%
#Create new DataFrame fitting weather criteria
#Narrow down the cities to fit weather conditions.
#Drop any rows will null values.

Best_Cities_DF = Weather_Data_DF.drop(Weather_Data_DF[(Weather_Data_DF["Max Temp"] < 150) 
                                                     | (Weather_Data_DF["Wind Speed"] > 5) 
                                                     | (Weather_Data_DF["Cloudiness"] != 0)
                                                     | (Weather_Data_DF["Humidity"] > 30)
                                                    ].index
                                    )

# %%
Best_Cities_DF
# Out:
#                    City  City_ID Country  Latitude  Longitude  Temperature  \
# 33                Maham  1264455      IN   28.9833    76.3000       312.92
# 57               Shache  1280037      CN   38.4167    77.2406       305.70
# 100       Bereznehuvate   712339      UA   47.3078    32.8499       305.53
# 125                Asău   686090      RO   46.4333    26.4000       300.66
# 153     Yangi Marg`ilon  1513491      UZ   40.4272    71.7189       303.55
# 191              Yulara  6355222      AU  -25.2406   130.9889       290.06
# 207                Jalu    86049      LY   29.0331    21.5482       306.51
# 220                 Hūn  2216645      LY   29.1268    15.9477       307.74
# 229              Yabrūd   162627      SY   33.9674    36.6574       296.22
# 235             Lugovoy  1521293      KZ   42.9472    72.7644       301.63
# 257        Grootfontein  3357114     NaN  -19.5667    18.1167       298.91
# 286              Waddān  2209055      LY   29.1614    16.1390       307.53
# 302       Alice Springs  2077895      AU  -23.7000   133.8833       286.90
# 317         Miandrivazo  1059051      MG  -19.5167    45.4667       303.72
# 335               Saýat  1218436      TM   38.7839    63.8803       308.08
# 404           Güzelyurt   313199      TR   38.2772    34.3719       297.59
# 446               Opuwo  3354077     NaN  -18.0607    13.8400       301.17
# 468              Riyadh   108410      SA   24.6877    46.7219       315.18
# 484             Senanga   898947      ZM  -16.1167    23.2667       302.20
# 506  Macieira de Cambra  2738052      PT   40.8594    -8.3734       294.85
# 525             Crotone  2524881      IT   39.0851    17.1178       310.12
# 546       Uşak Province   298298      TR   38.5000    29.4167       304.14
# 572                Aksu  1529660      CN   41.1231    80.2644       301.82
#
#      Humidity  Max Temp  Wind Speed  Cloudiness
# 33         26    312.92        3.69           0
# 57         14    305.70        4.88           0
# 100        30    305.53        2.77           0
# 125        25    305.24        3.00           0
# 153        19    303.83        3.09           0
# 191        17    290.06        2.57           0
# 207        29    306.51        3.38           0
# 220        18    307.74        1.76           0
# 229        12    296.22        2.20           0
# 235        21    301.63        4.06           0
# 257        22    298.91        3.09           0
# 286        18    307.53        1.15           0
# 302        19    286.90        3.60           0
# 317        24    303.72        1.80           0
# 335         9    308.08        3.31           0
# 404        29    297.59        4.20           0
# 446        17    301.17        3.78           0
# 468         9    315.18        2.06           0
# 484        20    302.20        2.30           0
# 506        30    298.81        0.85           0
# 525        26    310.12        2.57           0
# 546        14    304.14        2.08           0
# 572        15    301.82        2.40           0

# %%
print("Total number of cities is : " + str(len(Best_Cities_DF)))
# Out:
# Total number of cities is : 23

# %%
#Hotel Map
#Store into variable named hotel_df.
hotel_df = Best_Cities_DF

# %%
Best_Cities_DF["Hotel"] = ""

Best_Cities_DF.head()
# Out:
#                 City  City_ID Country  Latitude  Longitude  Temperature  \
# 33             Maham  1264455      IN   28.9833    76.3000       312.92
# 57            Shache  1280037      CN   38.4167    77.2406       305.70
# 100    Bereznehuvate   712339      UA   47.3078    32.8499       305.53
# 125             Asău   686090      RO   46.4333    26.4000       300.66
# 153  Yangi Marg`ilon  1513491      UZ   40.4272    71.7189       303.55
#
#      Humidity  Max Temp  Wind Speed  Cloudiness Hotel
# 33         26    312.92        3.69           0
# 57         14    305.70        4.88           0
# 100        30    305.53        2.77           0
# 125        25    305.24        3.00           0
# 153        19    303.83        3.09           0

# %%
#**********************TEST************************
#**************************************************

#Set parameters to search for hotels with 5000 meters.
#Hit the Google Places API for each city's coordinates.
#Store the first Hotel result into the DataFrame.
#Plot markers on top of the heatmap.

params = {
    "location": "23.47, 73.30",
    "Keyword" : "international airport",
    "radius": 5000,
    "types": "hotel",
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#base_url = "https://maps.googleapis.com/maps/api/place/details/json?"


# run a request using our params dictionary
response = requests.get(base_url, params=params)
#print(response)


# convert response to json
response_Json = response.json()
#print(response_Json)
print(json.dumps(response_Json, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "Aap_uEDSY-ZXFlqxd8LiBkitVA4gkNZiOkUqkLytFvO6xX1qBB8g0NLrBA3jyg5qepYbj7v9J63n00bjDpNRKIceq7-mOwD9vXDmo4IL9qSY6iAy_6JXujwBIVy9umoR1gLTVOt5SgtMLPUeVvlPreu-ygTx4r2zchvKO9GTO-I3rqVD5Uqvk3vGhJ68LPlKE0B-31Y_irN_GhN-xzr1r--XhTE5fhphNBDoeN9Xmxim76ALbmS2xwHId68MyUQJBAtTEfNxVSVRUEJFKKMkdzdBLKafmJaw82wzV_q77Mu5GewaPKaT9-umdTGYzfMxsu-xaAuKw1wOBtOgFnH9HotmzGgpRnjuba5EWZ-b-BR3pa05m8EzeeM3q3pX9wbf6pIbPtpvHXmvaBXRtLitwu7jB1Wd6pXxG7sGtb829eKuxrO0CMZs2xcuLg",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 23.464311,
#                     "lng": 73.29875779999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4848003266135,
#                         "lng": 73.31947486467098
#                     },
#                     "southwest": {
#                         "lat": 23.4401752596789,
#                         "lng": 73.28142634713588
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_pinlet",
#             "name": "Modasa",
#             "photos": [
#                 {
#                     "height": 2268,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110054323532968376789\">ashish trivedi</a>"
#                     ],
#                     "photo_reference": "Aap_uEDq_f7T0ldnKH1OuN-Zz0-kg7asmzZdYbb6sduAx4kRm1E5Oq3qB6B6cdU3ilR8HUwgauhkdjkf3E8gIS-0pTmp4I9l1yrHqN4XFbzOow2combdaVTdJLJcmQDKSYcekOza3KY4nrMJWtrNK45k3sYntDGhkIhMbrsswXUZGXV7DFhx",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ68Dh-DXwXTkRmzayb7Loj2U",
#             "reference": "ChIJ68Dh-DXwXTkRmzayb7Loj2U",
#             "scope": "GOOGLE",
#             "types": [
#                 "locality",
#                 "political"
#             ],
#             "vicinity": "Modasa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 23.4934373,
#                     "lng": 73.3003306
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4949570302915,
#                         "lng": 73.3016054802915
#                     },
#                     "southwest": {
#                         "lat": 23.4922590697085,
#                         "lng": 73.2989075197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet",
#             "name": "Government Engineering College, Modasa",
#             "photos": [
#                 {
#                     "height": 421,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101714781732750859884\">Sarang Rajvansh</a>"
#                     ],
#                     "photo_reference": "Aap_uEB2DU-XP0oYqcXutqlFMSCrFq7WOwMLriZWotDEA2glVd4ifeqIjdxpuIjXj0gXMtDe4rRoBLXWbzfGWZpFL2qefz62WIggbOWZgZkUx-wZnuTmTlAeWXpjCk2Oh8acx4BEP0yuFtI9wwtjgMeX_1Nlyf-UbZf92CR9cP2MgtjHJZDn",
#                     "width": 719
#                 }
#             ],
#             "place_id": "ChIJedSrzZTxXTkRzwa7ezTyafY",
#             "plus_code": {
#                 "compound_code": "F8V2+94 Modasa, Gujarat, India",
#                 "global_code": "7JMMF8V2+94"
#             },
#             "rating": 4.2,
#             "reference": "ChIJedSrzZTxXTkRzwa7ezTyafY",
#             "scope": "GOOGLE",
#             "types": [
#                 "university",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 324,
#             "vicinity": "Shamlaji Road, Aravali District, Modasa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 23.466809,
#                     "lng": 73.29135099999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4681582802915,
#                         "lng": 73.2927198302915
#                     },
#                     "southwest": {
#                         "lat": 23.4654603197085,
#                         "lng": 73.2900218697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_pinlet",
#             "name": "Sanjay V. Bhoi Freelance Accountant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJd81t38zxXTkRuztl8XUF1wE",
#             "plus_code": {
#                 "compound_code": "F78R+PG Modasa, Gujarat, India",
#                 "global_code": "7JMMF78R+PG"
#             },
#             "rating": 3,
#             "reference": "ChIJd81t38zxXTkRuztl8XUF1wE",
#             "scope": "GOOGLE",
#             "types": [
#                 "accounting",
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Sarvjanik Hospital Road, Modasa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 23.479026,
#                     "lng": 73.29662499999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4804417802915,
#                         "lng": 73.29777973029151
#                     },
#                     "southwest": {
#                         "lat": 23.4777438197085,
#                         "lng": 73.29508176970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_pinlet",
#             "name": "Monita Baking Industries| Canapes| Taco Basket| Chat Basket| Plain Wafer| Ice-cream Cones| edible spoon| edible cutlery| use and eat spoon|",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 350,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110390513422212790227\">Monita Baking Industries</a>"
#                     ],
#                     "photo_reference": "Aap_uEBtS8Drdx6tST-hYNXCZqe9TDpRUkzSULpS0x3YW235DQSmFrHqlB9soq_24Xu4FFCKH1HtwNBwWys0ByVROzQUMHRqGtUIRmParEWVCOr2ACZmxW6LFcU69BtcsVkAXyR_XQIuwzAKrDBqZtbP0wG0TMIh-XjcK-qXbUljkaUZyCGI",
#                     "width": 500
#                 }
#             ],
#             "place_id": "ChIJ-0HUsDXwXTkRed3Ua1LM-qs",
#             "plus_code": {
#                 "compound_code": "F7HW+JM Modasa, Gujarat, India",
#                 "global_code": "7JMMF7HW+JM"
#             },
#             "rating": 5,
#             "reference": "ChIJ-0HUsDXwXTkRed3Ua1LM-qs",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "134-GIDC Phase-2, Ganeshpura, Modasa shamlaji highway, Modasa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 23.4533323,
#                     "lng": 73.2886711
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4548909302915,
#                         "lng": 73.2898286802915
#                     },
#                     "southwest": {
#                         "lat": 23.4521929697085,
#                         "lng": 73.28713071970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet",
#             "name": "Shri J.B. Shah English Medium School",
#             "photos": [
#                 {
#                     "height": 960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103805267728485707206\">YASHRAJSINH DABHI</a>"
#                     ],
#                     "photo_reference": "Aap_uEAtH1zYXPz1CA6_oLn9Ol6bR_hKMyKeJtbe4M54PUyHaYwQoMta3mfhhPE-PcTucYSAJ1OAxkO2Zmcjhk1OwkjaiYMdgO_vbD06MhCEVwQh4aleZuKOiu0akOJ7vDQBCmPtp6XaJ-RmUaPKkKjshnCjDUidF8JgtXu4aIl-GQGSyXFQ",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJ6yGGrjrwXTkRasDOdPWswPc",
#             "plus_code": {
#                 "compound_code": "F73Q+8F Modasa, Gujarat, India",
#                 "global_code": "7JMMF73Q+8F"
#             },
#             "rating": 4.5,
#             "reference": "ChIJ6yGGrjrwXTkRasDOdPWswPc",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 84,
#             "vicinity": "Dhansura Road, College Campus, Modasa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 23.4628732,
#                     "lng": 73.2983078
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4642167302915,
#                         "lng": 73.29965433029149
#                     },
#                     "southwest": {
#                         "lat": 23.46151876970849,
#                         "lng": 73.29695636970848
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_pinlet",
#             "name": "Honey electronics",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 810,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118169581107466819403\">Honey electronics</a>"
#                     ],
#                     "photo_reference": "Aap_uEBgMnHT5HejVK6A40Wzhw4r0JcZm18BPhS8y9ENrxkHRwllq0x633K1OCGwPgl36A0GLgEP20ZtBu-FVXET7FX5slV_-SsTfMqpWDcjukCxWjV7MqGOtxO_K5wrVVGm5dOv_Mwd2hV0IXELJq8sijv-AhFlH-lBlu7HV2z6BmpNWfeM",
#                     "width": 1440
#                 }
#             ],
#             "place_id": "ChIJvdivrzXwXTkRuWgRhznzz0s",
#             "plus_code": {
#                 "compound_code": "F77X+48 Modasa, Gujarat, India",
#                 "global_code": "7JMMF77X+48"
#             },
#             "rating": 3.6,
#             "reference": "ChIJvdivrzXwXTkRuWgRhznzz0s",
#             "scope": "GOOGLE",
#             "types": [
#                 "bank",
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 20,
#             "vicinity": "Near modasa highschool S.T ROAD INFRONT BANK OF BARODA, Modasa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 23.4586825,
#                     "lng": 73.2943188
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4601010802915,
#                         "lng": 73.2955890802915
#                     },
#                     "southwest": {
#                         "lat": 23.45740311970849,
#                         "lng": 73.2928911197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "Janta Electricals",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100089528500007822615\">Janta Electricals</a>"
#                     ],
#                     "photo_reference": "Aap_uECCiZkn_U75LI07GCIeB5CC-K7I3iZfLVoT_walaMSGyKh0cj0Y-ubF9leMaV6A0ZmIglisyVGAXpN_NcmWdXL2f9wK8b39htQISCmWpqDFSsgXIG8-sIEqV4S_VRV9qzE9vBnu7BIDLHk7ZEhhE6kgGjQxsizKkT-ThNj02s2GPAC9",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJnTGHyjbwXTkRjmAiVWluwEs",
#             "plus_code": {
#                 "compound_code": "F75V+FP Modasa, Gujarat, India",
#                 "global_code": "7JMMF75V+FP"
#             },
#             "rating": 5,
#             "reference": "ChIJnTGHyjbwXTkRjmAiVWluwEs",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Alap complex, Nr thakkar petrol pump, College Road, Modasa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 23.4621064,
#                     "lng": 73.3032788
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4634116302915,
#                         "lng": 73.30466993029151
#                     },
#                     "southwest": {
#                         "lat": 23.4607136697085,
#                         "lng": 73.30197196970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bank-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/bank-intl_pinlet",
#             "name": "Union Bank Of India",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112452541690010836308\">Bhavik Patel</a>"
#                     ],
#                     "photo_reference": "Aap_uEAUvQ-5U4sRCCPEKCwzhBXWykkjANjvHCTDe3mMS_Mqy5GA1Vm16_Y5KzSYuvIOrsdYu4u2VJXrs13S5n1YUIhTSX0P_Oz-CW0X1ynhpwVnMb2my2zVlHnPBibbeDZiBFuBZOZpMsAKXOnUOKhkqNeh_sInqvNZWSe6rD4AHB4NbP9z",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJl54CzUvwXTkRfUYRwkPyQjI",
#             "plus_code": {
#                 "compound_code": "F863+R8 Modasa, Gujarat, India",
#                 "global_code": "7JMMF863+R8"
#             },
#             "rating": 4.2,
#             "reference": "ChIJl54CzUvwXTkRfUYRwkPyQjI",
#             "scope": "GOOGLE",
#             "types": [
#                 "bank",
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 24,
#             "vicinity": "Pushpak Complex, 5, Shyamnagar Opp. ITI, Malpur Road, Dist, Modasa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 23.48073789999999,
#                     "lng": 73.298332
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4820130802915,
#                         "lng": 73.2996681802915
#                     },
#                     "southwest": {
#                         "lat": 23.4793151197085,
#                         "lng": 73.2969702197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_pinlet",
#             "name": "BAKEWELL BISCUITS PVT. LTD.",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109615634835510729710\">BAKEWELL BISCUITS PVT. LTD.</a>"
#                     ],
#                     "photo_reference": "Aap_uEDk0Vl21h5Jkw98ittV-ajRFPVHyaYVPCxF2EVtKqwd2eWzO85vctxzfkk3Yx6b6rPpbgiDbGLxSFH-gHDdbFoSoXM1ibZIfWVOUibNRFKH_zDQXix6ntU3D7G__IlHN5AymhM3ji0HQzD6R0lLeONkBpMLylQizFX4NdychaXm_Qm_",
#                     "width": 5184
#                 }
#             ],
#             "place_id": "ChIJAXiRoDbwXTkRNIA8rZr5AAE",
#             "plus_code": {
#                 "compound_code": "F7JX+78 Modasa, Gujarat, India",
#                 "global_code": "7JMMF7JX+78"
#             },
#             "rating": 4.5,
#             "reference": "ChIJAXiRoDbwXTkRNIA8rZr5AAE",
#             "scope": "GOOGLE",
#             "types": [
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 23,
#             "vicinity": "Plot No. 33 to 38, G.I.D.C Ganeshpur, Modasa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 23.467736,
#                     "lng": 73.2954893
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4690943802915,
#                         "lng": 73.2968561802915
#                     },
#                     "southwest": {
#                         "lat": 23.4663964197085,
#                         "lng": 73.29415821970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet",
#             "name": "Bright Junior Science College",
#             "photos": [
#                 {
#                     "height": 4000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116674876392992085035\">Dr.Yash Patel</a>"
#                     ],
#                     "photo_reference": "Aap_uEBUxFYxYxplT2abx6godMTlvNsf5OEPZm6RVDxOGrM1-Obm8BE6kvq0pBjQ8nkD_ueogeMgWaDjTIoozs04anl9OcknuZ9zSThP852St-whUpndzKKCDVrMqNPwoIyvSJ4fauO3xHEyWA4_wYqvgcTvCFBbWttR5LNTwDv4IFkV8QMR",
#                     "width": 3000
#                 }
#             ],
#             "place_id": "ChIJ3ZBj1zbwXTkRtdFVjALxF48",
#             "plus_code": {
#                 "compound_code": "F79W+35 Modasa, Gujarat, India",
#                 "global_code": "7JMMF79W+35"
#             },
#             "rating": 4.4,
#             "reference": "ChIJ3ZBj1zbwXTkRtdFVjALxF48",
#             "scope": "GOOGLE",
#             "types": [
#                 "university",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 75,
#             "vicinity": "Shamlaji Road, Modasa - Aniyor Road, Modasa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 23.4635857,
#                     "lng": 73.2982576
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4648868802915,
#                         "lng": 73.29959008029151
#                     },
#                     "southwest": {
#                         "lat": 23.4621889197085,
#                         "lng": 73.29689211970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bank-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/bank-intl_pinlet",
#             "name": "Sabarkantha District Cooperative Bank",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJJ7CICTXwXTkRose8mCfmmes",
#             "plus_code": {
#                 "compound_code": "F77X+C8 Modasa, Gujarat, India",
#                 "global_code": "7JMMF77X+C8"
#             },
#             "rating": 4,
#             "reference": "ChIJJ7CICTXwXTkRose8mCfmmes",
#             "scope": "GOOGLE",
#             "types": [
#                 "bank",
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 7,
#             "vicinity": "SH 59, Modasa"
#         },
#         {
#             "business_status": "CLOSED_TEMPORARILY",
#             "geometry": {
#                 "location": {
#                     "lat": 23.4627887,
#                     "lng": 73.300513
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.46414428029151,
#                         "lng": 73.3018480302915
#                     },
#                     "southwest": {
#                         "lat": 23.4614463197085,
#                         "lng": 73.29915006970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet",
#             "name": "Sunrise Electrics Appliances",
#             "permanently_closed": true,
#             "photos": [
#                 {
#                     "height": 768,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110867635504357649772\">Sunrise Electrics Appliances</a>"
#                     ],
#                     "photo_reference": "Aap_uEDTk6zSvuF99xin6osskR6PzdFaMDoPiqXIreGOZbYjLzU3BJ1LN0SSl5wBiuG_2N3rmynhps7I0Vy3gSLnMYLDN4XnAW-XMvlBEIX8EPcYWZJA3WcNNwcpqxFYwKIVx8_4_pteTwsYSxVl7tokD4Ewf4HW633mWaKfxyq4xiLwqUbR",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJkyMscUrwXTkRNr98ids5Fno",
#             "plus_code": {
#                 "compound_code": "F872+46 Modasa, Gujarat, India",
#                 "global_code": "7JMMF872+46"
#             },
#             "rating": 4.9,
#             "reference": "ChIJkyMscUrwXTkRNr98ids5Fno",
#             "scope": "GOOGLE",
#             "types": [
#                 "secondary_school",
#                 "school",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 15,
#             "vicinity": "High School, G/25 Syamsundercomplex, opp. Modasa, Modasa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 23.4650375,
#                     "lng": 73.2987029
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4663983302915,
#                         "lng": 73.3001179302915
#                     },
#                     "southwest": {
#                         "lat": 23.4637003697085,
#                         "lng": 73.2974199697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bank-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/bank-intl_pinlet",
#             "name": "State Bank of India",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1967,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108290089710538847981\">Akash Patel</a>"
#                     ],
#                     "photo_reference": "Aap_uECS93YfuZ-V7krfSRHDgfkOpJxucCKPH_yX9O9gIwr3QrmqJozIWq_eMMS2fSK0D62j85o6-UAU0xXAGk5aKP_43ncVF-Q1VPtsnJgMoLalNyzQNn6X1FSb8ChRqHoA1-rlZRn4gXG-wxM0s1PLZ5-qsNBcqRO0-dgLMShMeP6ZjS-F",
#                     "width": 3354
#                 }
#             ],
#             "place_id": "ChIJ0UffajXwXTkRCzOn7AQU_7U",
#             "plus_code": {
#                 "compound_code": "F78X+2F Modasa, Gujarat, India",
#                 "global_code": "7JMMF78X+2F"
#             },
#             "rating": 3.4,
#             "reference": "ChIJ0UffajXwXTkRCzOn7AQU_7U",
#             "scope": "GOOGLE",
#             "types": [
#                 "atm",
#                 "bank",
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 43,
#             "vicinity": "CHAR RASTA, Gujarat State Highway 59, Modasa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 23.4660225,
#                     "lng": 73.302764
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4672889302915,
#                         "lng": 73.3041498302915
#                     },
#                     "southwest": {
#                         "lat": 23.4645909697085,
#                         "lng": 73.30145186970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_pinlet",
#             "name": "BSNL Office",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJwSD1J0vwXTkRYEIUmhho-Uc",
#             "plus_code": {
#                 "compound_code": "F883+C4 Modasa, Gujarat, India",
#                 "global_code": "7JMMF883+C4"
#             },
#             "rating": 3.6,
#             "reference": "ChIJwSD1J0vwXTkRYEIUmhho-Uc",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 36,
#             "vicinity": "Gujarat State Highway 146, Alankar Society, Modasa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 23.4621391,
#                     "lng": 73.2987267
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4637012802915,
#                         "lng": 73.3001852302915
#                     },
#                     "southwest": {
#                         "lat": 23.4610033197085,
#                         "lng": 73.2974872697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet",
#             "name": "Sarvoday High School",
#             "photos": [
#                 {
#                     "height": 2160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109560778714545199791\">ER.PRANAV JAIN</a>"
#                     ],
#                     "photo_reference": "Aap_uEAfIW3SAibeGKgrjmAs1SwSIsONRo7pLEAwE8Ksx5NeTlshmz9pIzzXVy9lsmwRpDL1-zd7U9ZeXkyyXGOVKBljw4_c7WahYbRe_YT9EZIvnlbD48nT5c9kgyp-5-_noxacGjsaxEFrRnSxPRCcTt5IoDBeUAcqk1jscDN0h2sVRf0",
#                     "width": 3600
#                 }
#             ],
#             "place_id": "ChIJsfBGlTXwXTkRsxx5WaaWWSE",
#             "plus_code": {
#                 "compound_code": "F76X+VF Modasa, Gujarat, India",
#                 "global_code": "7JMMF76X+VF"
#             },
#             "rating": 4.2,
#             "reference": "ChIJsfBGlTXwXTkRsxx5WaaWWSE",
#             "scope": "GOOGLE",
#             "types": [
#                 "school",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 22,
#             "vicinity": "SH 59, Rabarivas, ITI Area, Modasa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 23.4644655,
#                     "lng": 73.2969024
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4657797302915,
#                         "lng": 73.2982410802915
#                     },
#                     "southwest": {
#                         "lat": 23.4630817697085,
#                         "lng": 73.29554311970848
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_pinlet",
#             "name": "BSNL Office",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4608,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109883836107234181546\">pratik patel</a>"
#                     ],
#                     "photo_reference": "Aap_uEAdYCyKO_ELWxHfu5DU1SikiBLFaX6J72Wnt4bDJ3OgmGeiPdg4KHxXUlUXjc4gKcVY3VumHYmoJgBHEAkD1V-QjNSDx-ciNRnyRnmYzJisVPcUOG-woMh3gvAne3jLojrYZyD_lr_NtTqI0fwhl9nuK6YezTD8-G4PTvZfMRcd8GHG",
#                     "width": 3456
#                 }
#             ],
#             "place_id": "ChIJ8dYR4jTwXTkR1mWJzt1E8Do",
#             "plus_code": {
#                 "compound_code": "F77W+QQ Modasa, Gujarat, India",
#                 "global_code": "7JMMF77W+QQ"
#             },
#             "rating": 3.4,
#             "reference": "ChIJ8dYR4jTwXTkR1mWJzt1E8Do",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 19,
#             "vicinity": "Post office, Modasa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 23.4645418,
#                     "lng": 73.29710589999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4658064302915,
#                         "lng": 73.2983888302915
#                     },
#                     "southwest": {
#                         "lat": 23.4631084697085,
#                         "lng": 73.2956908697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/civic-bldg_pinlet",
#             "name": "Modasa Post Office",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2048,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117917797537041274786\">Megh Thekdi</a>"
#                     ],
#                     "photo_reference": "Aap_uEAzRc4pc_iZ5Xdh6p6FFmLdeHqs1u4jct0c2JKlfXrxnuk3ZP3RAHWtS0BPVCAV-ilnBUmRb_c02z0zXkSpqBas2LudG9xu8VlMyJne3A1s2sVphhlucYF99F_fvEqHGOydw06ZgKlK-Q2eOLZmYlYRn4uNnjFQDLt6rfppviTJ90vK",
#                     "width": 1536
#                 }
#             ],
#             "place_id": "ChIJUezQ4TTwXTkRo8bMQflKRtE",
#             "plus_code": {
#                 "compound_code": "F77W+RR Modasa, Gujarat, India",
#                 "global_code": "7JMMF77W+RR"
#             },
#             "rating": 3.7,
#             "reference": "ChIJUezQ4TTwXTkRo8bMQflKRtE",
#             "scope": "GOOGLE",
#             "types": [
#                 "post_office",
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 42,
#             "vicinity": "Modasa Off SH 59 near Police Station, Bazar Road, Deep Road, Modasa"
#         },
#         {
#             "business_status": "CLOSED_TEMPORARILY",
#             "geometry": {
#                 "location": {
#                     "lat": 23.4643362,
#                     "lng": 73.29834679999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.4657251802915,
#                         "lng": 73.2997134302915
#                     },
#                     "southwest": {
#                         "lat": 23.46302721970849,
#                         "lng": 73.29701546970848
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_pinlet",
#             "name": "Patel Travels Agency",
#             "permanently_closed": true,
#             "place_id": "ChIJiz06EjXwXTkRZ49nd26q14I",
#             "plus_code": {
#                 "compound_code": "F77X+P8 Modasa, Gujarat, India",
#                 "global_code": "7JMMF77X+P8"
#             },
#             "rating": 4.2,
#             "reference": "ChIJiz06EjXwXTkRZ49nd26q14I",
#             "scope": "GOOGLE",
#             "types": [
#                 "travel_agency",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 34,
#             "vicinity": "near POLICE CHOKI, C/O- PATEL CLOTH STORES, CHAR RASTA ,MODASA, near POLICE CHOKI, Modasa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 23.4652295,
#                     "lng": 73.296623
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.46660718029151,
#                         "lng": 73.29798848029151
#                     },
#                     "southwest": {
#                         "lat": 23.4639092197085,
#                         "lng": 73.2952905197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "Maniar Colours Bangles",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102592889164110511992\">nehal gandhi</a>"
#                     ],
#                     "photo_reference": "Aap_uEDgFxEBI6dPnEIk9ygaSJjwZpfI7o8cCbfawHvOnn7CzeAxQmE1Rk1pGJjyg0Zcf80iSgO1eK6MWv6wHGzrRp7VbRo_UFLSWPtM-658gS6SbLOBf_4EQWYOM_ohCVXyDcCmnU70smJPQ_jlPSrVDS2PxHzX7cNGn_EK6bsebK5DMLZx",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJwTcnoTbwXTkRnFMElzFjsfU",
#             "plus_code": {
#                 "compound_code": "F78W+3J Modasa, Gujarat, India",
#                 "global_code": "7JMMF78W+3J"
#             },
#             "rating": 3.9,
#             "reference": "ChIJwTcnoTbwXTkRnFMElzFjsfU",
#             "scope": "GOOGLE",
#             "types": [
#                 "shopping_mall",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 13,
#             "vicinity": "behind DENA BANK, Sarvajanik Hospital Road, Modasa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 23.4742527,
#                     "lng": 73.2912784
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.48576003292365,
#                         "lng": 73.29992994432128
#                     },
#                     "southwest": {
#                         "lat": 23.46258997315938,
#                         "lng": 73.28200006403046
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_pinlet",
#             "name": "Ganeshpur",
#             "photos": [
#                 {
#                     "height": 4608,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107701258466126048267\">Bharakumar Patel</a>"
#                     ],
#                     "photo_reference": "Aap_uEAM9zcPux7dZ3U9YpFp5diilPEGTU1vS2t-nhrrVejWFKDntD9qE3ZFWAVihBsWOEmZKmz__jy6ckvzW4vVUDYFohYdVtsQy2cQU3WOllqhxPgnXrNUFRNLbOuQtnqidQ7wg5nk1c6j4u3pi5tuWmiKVd9BPP4J_kYjdQddMlv0pJ8r",
#                     "width": 3456
#                 }
#             ],
#             "place_id": "ChIJQXqwVM7xXTkRo359-2O5NkE",
#             "reference": "ChIJQXqwVM7xXTkRo359-2O5NkE",
#             "scope": "GOOGLE",
#             "types": [
#                 "locality",
#                 "political"
#             ],
#             "vicinity": "Ganeshpur"
#         }
#     ],
#     "status": "OK"
# }

# %%
#Set parameters to search for hotels with 5000 meters.
#Hit the Google Places API for each city's coordinates.
#Store the first Hotel result into the DataFrame.
#Plot markers on top of the heatmap.


# create a params dict that will be updated with new city each iteration
params = {"radius": 5000,
          "type": "Hotel",
          "keyword" : "Hotel",
          "key": g_key
         }

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#base_url = "https://maps.googleapis.com/maps/api/place/details/json?"



# Loop through the cities_pd and run a lat/long search for each city
for index, row in hotel_df.iterrows():

    Lat = row['Latitude']
    Long = row['Longitude']
    #CityID = row["City_ID"]
    
    # update address key value
    params['location'] = f"{Lat},{Long}"    
    #pprint(params)

    # make request
    Response = requests.get(base_url, params=params)
    #print(Response)
          
    # convert to json
    Response_JSON = Response.json()
    #pprint(Response_JSON)
    
    # extract results
    results = Response_JSON['results']
    pprint(results)

    try:
        print(f"Closest hotel is {results[0]['name']}.")
        hotel_df.loc[index, "Hotel"] = Response_JSON["results"][0]["name"]
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 28.9639063, 'lng': 76.29973},
#                'viewport': {'northeast': {'lat': 28.96527082989272,
#                                           'lng': 76.30108182989272},
#                             'southwest': {'lat': 28.96257117010728,
#                                           'lng': 76.29838217010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Chobisi Hotel, Meham',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1280,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/107849670674381105939">A '
#                                     'Google User</a>'],
#               'photo_reference': 'Aap_uECnrnd1p29IqNOylFQclz263rT4UYV9tk1dyY87YTDG5YtyDIbXKXL37FOaA4hWZc40LqTjIj0LYjKEX90OuTvwDH0CgD0cF9Enh7vwBUT0e21QrIvQEXT67dGjYuUx3-7nuUkTf1YqswAASS3TX0Z878tpbNR5J3Yldo9kidkqiBxD',
#               'width': 960}],
#   'place_id': 'ChIJxSTzgL5xEjkRAIpb2InahKs',
#   'plus_code': {'compound_code': 'X77X+HV Meham, Haryana, India',
#                 'global_code': '7JWRX77X+HV'},
#   'rating': 3.5,
#   'reference': 'ChIJxSTzgL5xEjkRAIpb2InahKs',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 105,
#   'vicinity': '1st Street on Bahalba Road Kishangarh, SH 16A, Meham'}]
# Closest hotel is Chobisi Hotel, Meham.
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 38.414382, 'lng': 77.24989},
#                'viewport': {'northeast': {'lat': 38.41573147989272,
#                                           'lng': 77.25112317989273},
#                             'southwest': {'lat': 38.41303182010727,
#                                           'lng': 77.24842352010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Shache Wanghou Hotel',
#   'place_id': 'ChIJg95SzVKy8zgR97Io6PmNkJg',
#   'plus_code': {'compound_code': 'C67X+QX Shachezhen, Yarkant County, Kashgar '
#                                  'Prefecture, Xinjiang, China',
#                 'global_code': '8JCVC67X+QX'},
#   'rating': 0,
#   'reference': 'ChIJg95SzVKy8zgR97Io6PmNkJg',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 0,
#   'vicinity': 'Kashgar Prefecture, Yarkant County, 大十字老城路口'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 38.415187, 'lng': 77.24785299999999},
#                'viewport': {'northeast': {'lat': 38.41650342989273,
#                                           'lng': 77.24920762989272},
#                             'southwest': {'lat': 38.41380377010728,
#                                           'lng': 77.24650797010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_pinlet',
#   'name': 'Shache Hotel',
#   'place_id': 'ChIJwfEjP1Oy8zgRYrZZ29fceag',
#   'rating': 0,
#   'reference': 'ChIJwfEjP1Oy8zgRYrZZ29fceag',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 0,
#   'vicinity': 'C68X+34H, Yarkant County, Kashgar Prefecture'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 38.414222, 'lng': 77.247519},
#                'viewport': {'northeast': {'lat': 38.41548242989272,
#                                           'lng': 77.24886912989273},
#                             'southwest': {'lat': 38.41278277010728,
#                                           'lng': 77.24616947010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Xinsheng Hotel',
#   'place_id': 'ChIJYfQdS1Oy8zgRXOY2OY1ogx0',
#   'plus_code': {'compound_code': 'C67X+M2 Shachezhen, Yarkant County, Kashgar '
#                                  'Prefecture, Xinjiang, China',
#                 'global_code': '8JCVC67X+M2'},
#   'rating': 0,
#   'reference': 'ChIJYfQdS1Oy8zgRXOY2OY1ogx0',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 0,
#   'vicinity': '4 Xincheng Rd, Yarkant County, Kashgar Prefecture'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 38.410356, 'lng': 77.247912},
#                'viewport': {'northeast': {'lat': 38.41162642989272,
#                                           'lng': 77.24926277989273},
#                             'southwest': {'lat': 38.40892677010728,
#                                           'lng': 77.24656312010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_pinlet',
#   'name': 'Diwang Business Hotel',
#   'place_id': 'ChIJIdSMQKyz8zgRrJd7OGwbrXs',
#   'rating': 0,
#   'reference': 'ChIJIdSMQKyz8zgRrJd7OGwbrXs',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 0,
#   'vicinity': 'C66X+45V, Yarkant County, Kashgar Prefecture'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 38.414192, 'lng': 77.238922},
#                'viewport': {'northeast': {'lat': 38.41545227989272,
#                                           'lng': 77.24027237989272},
#                             'southwest': {'lat': 38.41275262010728,
#                                           'lng': 77.23757272010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'New Century Hotel',
#   'place_id': 'ChIJ5Yabwf-y8zgRSggHORXCffc',
#   'plus_code': {'compound_code': 'C67Q+MH Gulebagezhen, Yarkant County, '
#                                  'Kashgar Prefecture, Xinjiang, China',
#                 'global_code': '8JCVC67Q+MH'},
#   'rating': 0,
#   'reference': 'ChIJ5Yabwf-y8zgRSggHORXCffc',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 0,
#   'vicinity': '44 Xincheng Rd, Yarkant County, Kashgar Prefecture'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 38.414288, 'lng': 77.23973099999999},
#                'viewport': {'northeast': {'lat': 38.41563752989272,
#                                           'lng': 77.24092792989272},
#                             'southwest': {'lat': 38.41293787010728,
#                                           'lng': 77.23822827010729}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Wuzi Commercial Hotel',
#   'place_id': 'ChIJma7u7f-y8zgRthnMK1AG2I8',
#   'plus_code': {'compound_code': 'C67Q+PV Gulebagezhen, Yarkant County, '
#                                  'Kashgar Prefecture, Xinjiang, China',
#                 'global_code': '8JCVC67Q+PV'},
#   'rating': 0,
#   'reference': 'ChIJma7u7f-y8zgRthnMK1AG2I8',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 0,
#   'vicinity': 'Wenhua Rd, Yarkant County, Kashgar Prefecture'}]
# Closest hotel is Shache Wanghou Hotel.
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 47.3071286, 'lng': 32.8455992},
#                'viewport': {'northeast': {'lat': 47.30845052989272,
#                                           'lng': 32.84695017989273},
#                             'southwest': {'lat': 47.30575087010727,
#                                           'lng': 32.84425052010729}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Tulip',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1080,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/104507360250081459029">Кургацкий '
#                                     'Виталий</a>'],
#               'photo_reference': 'Aap_uEAIDPQxHayzuFu2XXwQHYSON0Cwe-Q7vj2DAwnW-MHGLFrvYeCtLaO8b0aqiqGWAjilsH8NEendm6spE1VbveMhOHO0lF_7kKvOUL9sfUToKm7B68tc2Dccd1HekTdAKZ-eTPnmTrCkNne3QuV6DORLkGk1tkebHPPyE7Tc6GjdAlJB',
#               'width': 1920}],
#   'place_id': 'ChIJowHFZhLlxEARPLc-rqVxXRo',
#   'plus_code': {'compound_code': '8R4W+V6 Bereznehuvate, Mykolaiv Oblast, '
#                                  'Ukraine',
#                 'global_code': '8GVJ8R4W+V6'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJowHFZhLlxEARPLc-rqVxXRo',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 117,
#   'vicinity': 'Bereznehuvate'}]
# Closest hotel is Tulip.
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 46.421899, 'lng': 26.4403981},
#                'viewport': {'northeast': {'lat': 46.42327672989272,
#                                           'lng': 26.44191602989272},
#                             'southwest': {'lat': 46.42057707010727,
#                                           'lng': 26.43921637010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Pensiunea Sophia',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 5664,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/114369262263674604268">Ада</a>'],
#               'photo_reference': 'Aap_uEBBq7_I8SbBVbiy1p2quPLsOTNdhUaUShC25KH_384LROmOyUpeYzQV5g-byTq8bR9pOMInzLhs1pmQHl94I6ACS9yZeONr5JyCAjusvl9i5VVbpC-eh5gzHOCd93T4KPO-RBVCgdS3Lo8WEiLaPQs8x3s2RwGK-9kjJ5Um-bnJCXUx',
#               'width': 4248}],
#   'place_id': 'ChIJL8vhdwc9tUARn6g11Toi8y4',
#   'plus_code': {'compound_code': 'CCCR+Q5 Comănești, Romania',
#                 'global_code': '8GR8CCCR+Q5'},
#   'rating': 3.8,
#   'reference': 'ChIJL8vhdwc9tUARn6g11Toi8y4',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 225,
#   'vicinity': 'Strada Republicii 17, Comănești'}]
# Closest hotel is Pensiunea Sophia.
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 40.3967983, 'lng': 71.7652715},
#                'viewport': {'northeast': {'lat': 40.39826257989272,
#                                           'lng': 71.76676187989273},
#                             'southwest': {'lat': 40.39556292010728,
#                                           'lng': 71.76406222010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'TANTANA HOTEL FERGANA',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4024,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/104098576033244848152">A '
#                                     'Google User</a>'],
#               'photo_reference': 'Aap_uEBy2xLuvRoF9tgD_HuzHJek8cKbqTqf_IeZFmQn9TEi5mn9snJO103aUMEy6kg-mRKCjxRl4Uu0_NzdTnM6g6P0jB2XGDaqQGJDFkYXoKdsbGg_R6lpXCF8ZA36Cuv-oRK3s4043CM_EUbokDFd3gZtiDITiDdrRpypu6_Kp24EPx01',
#               'width': 6048}],
#   'place_id': 'ChIJ74fma66DuzgRo6u2fzAxPoQ',
#   'plus_code': {'compound_code': '9QW8+P4 Fergana, Uzbekistan',
#                 'global_code': '8JGH9QW8+P4'},
#   'rating': 4.7,
#   'reference': 'ChIJ74fma66DuzgRo6u2fzAxPoQ',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 13,
#   'vicinity': 'дом 122, Улица Алъ, Fergana'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 40.4682809, 'lng': 71.71804589999999},
#                'viewport': {'northeast': {'lat': 40.46963732989273,
#                                           'lng': 71.71933027989272},
#                             'southwest': {'lat': 40.46693767010728,
#                                           'lng': 71.71663062010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'ATLAS HOTEL',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 479,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/114764285182964484621">Давлатжон '
#                                     'Турсунов</a>'],
#               'photo_reference': 'Aap_uEBbXcqkeUrzkzcI9kOKNbs9ri9WcW5hzW2s7XMtxIfMVK__em24J1VJB2bWktMZWZcWUXInvSN4NEAGzclUFiM5Ay9McUwfbx0UO26acat2gx5Wd9IlHWMrkS5_O9IHEJ__L9j9PN6BKe2YeKTN7ImUKyOqH7DnRSfxno886lTEO9NF',
#               'width': 720}],
#   'place_id': 'ChIJaQI7MJV3uzgRmhqeCIHUd0M',
#   'plus_code': {'compound_code': 'FP99+86 Margilan, Uzbekistan',
#                 'global_code': '8JGHFP99+86'},
#   'rating': 4.6,
#   'reference': 'ChIJaQI7MJV3uzgRmhqeCIHUd0M',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 22,
#   'vicinity': '151101 г Маргилан, Turkistan Street, 119д'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 40.4416845, 'lng': 71.71644549999999},
#                'viewport': {'northeast': {'lat': 40.44298927989273,
#                                           'lng': 71.71764267989273},
#                             'southwest': {'lat': 40.44028962010729,
#                                           'lng': 71.71494302010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Diyor hotel',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3000,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/105019193117127251399">A '
#                                     'Google User</a>'],
#               'photo_reference': 'Aap_uEBfKnA-vTR9GhF7ooOp8MZ3xuvaJIDK8EpfeZD7rOpdMXW6E4hgv_1mc0WtU_1lUP1OnFmJ3acN18PLe9QyTD6E1S0qv7Mnf2sSiKMuFX_r_1VWFmnneDGvr01OP1URBog1D08n4aYO5dLsJ8pRCGkU3YH1n4u3aILcN4Nca4u0bnYD',
#               'width': 4000}],
#   'place_id': 'ChIJjRuZUaJ3uzgRwChDsDVzDRY',
#   'plus_code': {'compound_code': 'CPR8+MH Margilan, Uzbekistan',
#                 'global_code': '8JGHCPR8+MH'},
#   'rating': 4.8,
#   'reference': 'ChIJjRuZUaJ3uzgRwChDsDVzDRY',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 37,
#   'vicinity': 'Xiyobon 65-b Margilon, Фергана'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 40.3957637, 'lng': 71.76784789999999},
#                'viewport': {'northeast': {'lat': 40.39701402989272,
#                                           'lng': 71.76907537989273},
#                             'southwest': {'lat': 40.39431437010728,
#                                           'lng': 71.76637572010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Major Hotel',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 6000,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/117435614992544551426">A '
#                                     'Google User</a>'],
#               'photo_reference': 'Aap_uEA4I7GSKAeTjv-WFCgjm_19z3Nbv2Ml2kolyqIPUT21c152vk7jF86xsStmoHhbQG4KYNZQW0jxkZKfDmtd-Ds6jttfe9ZAcdr0P4HSqHukUtxPphaxUT1eNiw2fGSrfvGYJn7GtIU-VMxqd-bvR7FptGhX4EwedKANZA0rh3gqdrYt',
#               'width': 8000}],
#   'place_id': 'ChIJA-bKQQuDuzgRPLrJTj0D3CM',
#   'plus_code': {'compound_code': '9QW9+84 Fergana, Uzbekistan',
#                 'global_code': '8JGH9QW9+84'},
#   'rating': 5,
#   'reference': 'ChIJA-bKQQuDuzgRPLrJTj0D3CM',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 9,
#   'vicinity': 'Al-Fargoniy Street, Fergana'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 40.426498, 'lng': 71.771866},
#                'viewport': {'northeast': {'lat': 40.42785617989273,
#                                           'lng': 71.77321292989272},
#                             'southwest': {'lat': 40.42515652010728,
#                                           'lng': 71.77051327010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Гостиничный комплекс «Макон»',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2946,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/116354376178189919948">Kwanggeun '
#                                     'Tack</a>'],
#               'photo_reference': 'Aap_uEDQZbCmK0yVyoO2ny_zBPBJzLPdvvHPo5M_1Gv4zF0QXKbXeEaR16d91FAOGvhUOzAf8jwOYZjGfLe-4RNMRO8iAoLz-j7Qt6Fwyd9TEbnYt3QQ0AVi8dLjxC0U_mqWDFOy1Y-iV7O6qHs_Bwg0nWnZZG_7CXIAsWuLNE5Me5_FczwJ',
#               'width': 3904}],
#   'place_id': 'ChIJyZoBUNCCuzgRsfhtuY9uxMk',
#   'plus_code': {'compound_code': 'CQGC+HP Kirgili, Uzbekistan',
#                 'global_code': '8JGHCQGC+HP'},
#   'rating': 4.3,
#   'reference': 'ChIJyZoBUNCCuzgRsfhtuY9uxMk',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 15,
#   'vicinity': 'Ulitsa Ferganskaya, Kirgili'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 40.4614177, 'lng': 71.7283138},
#                'viewport': {'northeast': {'lat': 40.46268892989272,
#                                           'lng': 71.72975172989273},
#                             'southwest': {'lat': 40.45998927010728,
#                                           'lng': 71.72705207010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Ikathouse',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4032,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/104631350329160695669">Cheng-Tse</a>'],
#               'photo_reference': 'Aap_uEBWSaoJGmlJrivu7Ah1pQtiF6Je7aIAXlj69qzwyrxtecV1MtND616CVGDhynUMbTmR2pAJM0-J81gMFlXGMGfrU3V7QAeB2Q80gD0cQab4X5PuivA5eSqSrof9z8R-BKGckNkI14VhYe7JuJoXn83WK4HIzeHuq_m_wiWK9fseaY47',
#               'width': 3024}],
#   'place_id': 'ChIJQ6JNOMV3uzgRmb8v4n7T_wg',
#   'rating': 4.3,
#   'reference': 'ChIJQ6JNOMV3uzgRmb8v4n7T_wg',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 25,
#   'vicinity': 'FP6H+H88, Margilan'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 40.3983147, 'lng': 71.766603},
#                'viewport': {'northeast': {'lat': 40.39968397989272,
#                                           'lng': 71.76794452989273},
#                             'southwest': {'lat': 40.39698432010728,
#                                           'lng': 71.76524487010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Hotel "Soy bo‘yi"',
#   'photos': [{'height': 4160,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/106998864401440787675">A '
#                                     'Google User</a>'],
#               'photo_reference': 'Aap_uEBQdLKdqD7XxZaPfyQybgy2tw8FKk336K7mW3k-S71yWbg5ukxEZPBEOJs_wrW1P8R-q1EWB9pdEz-lOCpi4dwajvREo6aA2zT2xT06ND6s5gtb5i8GBMqzUL0QezxdOXGwixY-cdWXLkT_6kYLZJhtIWpUOgIS4p8d2okpVSsKFWFm',
#               'width': 3120}],
#   'place_id': 'ChIJDeD-wPyDuzgRI4svx1OcWsU',
#   'plus_code': {'compound_code': '9QX8+8J Fergana, Uzbekistan',
#                 'global_code': '8JGH9QX8+8J'},
#   'rating': 4,
#   'reference': 'ChIJDeD-wPyDuzgRI4svx1OcWsU',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1,
#   'vicinity': "Kichik Xalqa Yo'li, Fergana"},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 40.3804317, 'lng': 71.7766867},
#                'viewport': {'northeast': {'lat': 40.38176157989272,
#                                           'lng': 71.77813037989273},
#                             'southwest': {'lat': 40.37906192010728,
#                                           'lng': 71.77543072010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Minimalist',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/106147552160971064269">A '
#                                     'Google User</a>'],
#               'photo_reference': 'Aap_uEBitCY0DRtQQtai_8KN3sJpX8Xz6KWVouJuQ8txBED2e0sKKUVPjAbOU1fe2BzqaSWI8AXwt5No_FdzjW8R_4C7KB8yuDZVkLLnTOztLBD_TGln133sRReCR7aAVkqba1dAsqek_LlRcG-f9o5dAC48r9lHlAKmO8mLAm1cdXr5usyW',
#               'width': 4032}],
#   'place_id': 'ChIJny2b9C-DuzgRfX4NQO2Mb5E',
#   'rating': 5,
#   'reference': 'ChIJny2b9C-DuzgRfX4NQO2Mb5E',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 11,
#   'vicinity': '9QJG+5MF, Fergana'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 40.4305398, 'lng': 71.7710274},
#                'viewport': {'northeast': {'lat': 40.43188517989272,
#                                           'lng': 71.77233627989271},
#                             'southwest': {'lat': 40.42918552010727,
#                                           'lng': 71.76963662010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Makon hostel',
#   'place_id': 'ChIJASwcVc6CuzgRdmQMAjSt888',
#   'plus_code': {'compound_code': 'CQJC+6C Kirgili, Uzbekistan',
#                 'global_code': '8JGHCQJC+6C'},
#   'rating': 1,
#   'reference': 'ChIJASwcVc6CuzgRdmQMAjSt888',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1,
#   'vicinity': '82 Ulitsa Ferganskaya, Kirgili'}]
# Closest hotel is TANTANA HOTEL FERGANA.
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -25.240746, 'lng': 130.983085},
#                'viewport': {'northeast': {'lat': -25.23923642010728,
#                                           'lng': 130.9849370798927},
#                             'southwest': {'lat': -25.24193607989272,
#                                           'lng': 130.9822374201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'The Lost Camel Hotel - Ayers Rock Resort',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2739,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/101330567117106186052">A '
#                                     'Google User</a>'],
#               'photo_reference': 'Aap_uEAQsN5XCgHaX1gwVHyZt0wyJLMEZDk38HdTGy9oEU9bvi5tZP19c1nz2USHreCvlW9J2rP2sUHhTOU5AZR5SLlaWf3wf-1-PubDrPaO98SEfCHqRTu_keQXAb8n2mhF6ekcNN6WeCI0yOiqV2iFUkw326RKhskNMedTrSvtcrFrm7Du',
#               'width': 4134}],
#   'place_id': 'ChIJE_rnfv5BIysRj2HJFgoM3KI',
#   'plus_code': {'compound_code': 'QX5M+P6 Yulara, Northern Territory, '
#                                  'Australia',
#                 'global_code': '5Q6GQX5M+P6'},
#   'rating': 4,
#   'reference': 'ChIJE_rnfv5BIysRj2HJFgoM3KI',
#   'scope': 'GOOGLE',
#   'types': ['tourist_attraction',
#             'lodging',
#             'point_of_interest',
#             'establishment'],
#   'user_ratings_total': 288,
#   'vicinity': 'Ayers Rock, Yulara Dr, Yulara'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -25.2390223, 'lng': 130.9834051},
#                'viewport': {'northeast': {'lat': -25.23774217010728,
#                                           'lng': 130.9849756798928},
#                             'southwest': {'lat': -25.24044182989272,
#                                           'lng': 130.9822760201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Sails in the Desert',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2509,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/117718464637248251334">Sails '
#                                     'in the Desert</a>'],
#               'photo_reference': 'Aap_uECetTsdWdZTnFNdzHQw9eLQXd0S7ckh-1BKTMoFbUFu4G3yNi0-WR3CJBu4MXmfx4sYVDaf0qlwUTbXeXfVkdWHwo1gyU_UB1U-dBZtWcIlr1Z3L2SUuqqkzxvr4OvWuW30Zi_kByVZFY7X_Od8a0YUFnlLGEc8JlW8m7EJeJD4kBr0',
#               'width': 4134}],
#   'place_id': 'ChIJ24TZRSNAIysRt8XwXHPNLhQ',
#   'plus_code': {'compound_code': 'QX6M+99 Yulara, Northern Territory, '
#                                  'Australia',
#                 'global_code': '5Q6GQX6M+99'},
#   'rating': 4.2,
#   'reference': 'ChIJ24TZRSNAIysRt8XwXHPNLhQ',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1407,
#   'vicinity': '163 Yulara Dr, Yulara'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -25.2500597, 'lng': 131.0083166},
#                'viewport': {'northeast': {'lat': -25.24870132010728,
#                                           'lng': 131.0097069298927},
#                             'southwest': {'lat': -25.25140097989272,
#                                           'lng': 131.0070072701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Longitude 131',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4961,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/112872998718861615506">Longitude '
#                                     '131</a>'],
#               'photo_reference': 'Aap_uEBBG9Jjk-dFUyurALWPDUDXRsRxG-tsQzhR0_Ahalj1DhGfyQ2D4UMaijjleYvyvHJfG6aZgqPeiBrveywJ8rzJETRZis9IFqIQe8fKB2PADi5W0lbSDX1HTqTWJxvNI6LZDcAAYsi9cIvXer04nJMcSewj6iRPrJvMAYmmUIdLGlmR',
#               'width': 3308}],
#   'place_id': 'ChIJ24TZRSNAIysRwqrWEVV1tFs',
#   'plus_code': {'compound_code': 'P2X5+X8 Yulara, Northern Territory, '
#                                  'Australia',
#                 'global_code': '5Q6HP2X5+X8'},
#   'rating': 4.9,
#   'reference': 'ChIJ24TZRSNAIysRwqrWEVV1tFs',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 91,
#   'vicinity': 'Yulara Dr, Yulara'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -25.2430473, 'lng': 130.9896141},
#                'viewport': {'northeast': {'lat': -25.24172557010728,
#                                           'lng': 130.9908252298927},
#                             'southwest': {'lat': -25.24442522989272,
#                                           'lng': 130.9881255701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Outback Pioneer Hotel & Lodge - Ayers Rock Resort',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1108,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/107618500350361765996">A '
#                                     'Google User</a>'],
#               'photo_reference': 'Aap_uEA5DZGhqpfRtIaBYyaatC-3bLOj72y_a-Ah7V6mDv7ebN0UpZ4X0oqWeudsb410K1CfuQ1iothQOfN0oDlZYwxTrB-EFhpz84RM3LoFtTxEFCiYcsPr-_vbg3oZ2uc5cdmMmtIkRqJDSq-HUG4YlKu1vdepFSazxe2NyQ_Og6-OWq0',
#               'width': 2048}],
#   'place_id': 'ChIJ4fstXihAIysR81NwRnWuQTc',
#   'plus_code': {'compound_code': 'QX4Q+QR Yulara, Northern Territory, '
#                                  'Australia',
#                 'global_code': '5Q6GQX4Q+QR'},
#   'rating': 3.8,
#   'reference': 'ChIJ4fstXihAIysR81NwRnWuQTc',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1643,
#   'vicinity': '2 Yulara Dr, Yulara'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -25.243725, 'lng': 130.984807},
#                'viewport': {'northeast': {'lat': -25.24237502010727,
#                                           'lng': 130.9862289298927},
#                             'southwest': {'lat': -25.24507467989272,
#                                           'lng': 130.9835292701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Desert Gardens Hotel - Ayers Rock Resort',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2625,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/102790711887296946185">Desert '
#                                     'Gardens Hotel</a>'],
#               'photo_reference': 'Aap_uEBJHtEyP0-VgcXBFmPhPDbnw-8FHvuLNbtewhCIYNAW1do2sd6tcBMPIXbzxMhstz-2E3h-zbCc4U0PMOJz1-3QijZMjehvd4IA-Rowualuwy-gfv-KIyLKUmWRYzCTmmqXGWfQNuhr9vh02lB4mgmGoTaO0sVYtzdWZr_CSfjVBDH1',
#               'width': 3500}],
#   'place_id': 'ChIJ24TZRSNAIysRYjNts0ZvnUY',
#   'plus_code': {'compound_code': 'QX4M+GW Yulara, Northern Territory, '
#                                  'Australia',
#                 'global_code': '5Q6GQX4M+GW'},
#   'rating': 4.1,
#   'reference': 'ChIJ24TZRSNAIysRYjNts0ZvnUY',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1738,
#   'vicinity': '1 Yulara Dr, Yulara'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -25.239081, 'lng': 130.9834312},
#                'viewport': {'northeast': {'lat': -25.23779402010728,
#                                           'lng': 130.9849800298927},
#                             'southwest': {'lat': -25.24049367989272,
#                                           'lng': 130.9822803701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Ayers Rock Resort',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2509,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/109143776468969445613">A '
#                                     'Google User</a>'],
#               'photo_reference': 'Aap_uECfLOrxwC2UY3eWFnt_MijHox0rIdWSdCOQimYp7OUfDOjPj66arficdXCvogs1K513Z7fp6K3bz-uwjjxK222tKhAJt5oPX8Z1BW04zkjFGBbGShThd8evVVNfVAntFa4ns67uBIicGhNdYVUYlHFkieLwrg4uDdc42NbVZko1NC_i',
#               'width': 4134}],
#   'place_id': 'ChIJkVqJ2yRAIysRuAlQsdhjMXk',
#   'plus_code': {'compound_code': 'QX6M+99 Yulara, Northern Territory, '
#                                  'Australia',
#                 'global_code': '5Q6GQX6M+99'},
#   'rating': 4,
#   'reference': 'ChIJkVqJ2yRAIysRuAlQsdhjMXk',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 251,
#   'vicinity': '170 Yulara Dr, Yulara'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -25.2423403, 'lng': 130.9847999},
#                'viewport': {'northeast': {'lat': -25.24100432010728,
#                                           'lng': 130.9862456298927},
#                             'southwest': {'lat': -25.24370397989273,
#                                           'lng': 130.9835459701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Emu Walk Apartments - Ayers Rock Resort',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2625,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/108457519411478617282">A '
#                                     'Google User</a>'],
#               'photo_reference': 'Aap_uEA_2ZfQDo3kFT60iWM_p4sutUkFppCp3K4bdUu12qUkgVU-W8iFVZFdsJWeunjsTvzN3_F0ea4ThGKMLAKOX9xn2RJNkBNuOh5SOUVqiBwdNgu9NsR1VQCCyHJCWBnEbLzFqnAl5W95AnrSsWiUvQHF3qhnyBQ1OUysKsTS4R0Ud16h',
#               'width': 3500}],
#   'place_id': 'ChIJjVOgUSFAIysRJRxtLbfP-vc',
#   'plus_code': {'compound_code': 'QX5M+3W Yulara, Northern Territory, '
#                                  'Australia',
#                 'global_code': '5Q6GQX5M+3W'},
#   'rating': 4.4,
#   'reference': 'ChIJjVOgUSFAIysRJRxtLbfP-vc',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 331,
#   'vicinity': 'Ayers Rock Resort, 3 Yulara Dr, Yulara'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -25.238758, 'lng': 130.9902568},
#                'viewport': {'northeast': {'lat': -25.23743737010728,
#                                           'lng': 130.9914955798927},
#                             'southwest': {'lat': -25.24013702989272,
#                                           'lng': 130.9887959201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/camping-71.png',
#   'icon_background_color': '#4DB546',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/camping_pinlet',
#   'name': 'Ayers Rock Campground',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2738,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/112449263997726111965">Ayers '
#                                     'Rock Campground</a>'],
#               'photo_reference': 'Aap_uEC482OS9mtDK4p6PfUuPX_dExGPM-CDvLntj2Zz5icC4sP8MrOpVrtYLx2WxieH5j3gXWL93OgGuyI_UIzxLhK19js4fQINeSDvHnwbNk3x6NwuAN1AM852JqVruxU4PiZ5qRLVSTIC0FzmrqT2vQKOFCVLZmnXjLVvcqg62j72S66s',
#               'width': 4134}],
#   'place_id': 'ChIJt-TOuSZAIysR8C8HdCThC4E',
#   'plus_code': {'compound_code': 'QX6R+F4 Yulara, Northern Territory, '
#                                  'Australia',
#                 'global_code': '5Q6GQX6R+F4'},
#   'rating': 3.9,
#   'reference': 'ChIJt-TOuSZAIysR8C8HdCThC4E',
#   'scope': 'GOOGLE',
#   'types': ['campground',
#             'rv_park',
#             'lodging',
#             'park',
#             'point_of_interest',
#             'establishment'],
#   'user_ratings_total': 1353,
#   'vicinity': '173 Yulara Dr, Yulara'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -25.237715, 'lng': 130.9859721},
#                'viewport': {'northeast': {'lat': -25.23650027010728,
#                                           'lng': 130.9873189298927},
#                             'southwest': {'lat': -25.23919992989272,
#                                           'lng': 130.9846192701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Desert Gardens - A member of Novotel Hotels',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3456,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/117226874260703734058">Bluerental '
#                                     'Autonoleggio rent a car</a>'],
#               'photo_reference': 'Aap_uEAUaxvW3zKgtidd0kE6IBJTobPjJfqlM9UZ9DEEdHI1Edb_dFEN02eyG8NCjyId5LRV_a7IYvgDIyr88bDmt28cMXMsR3n_vQ9-fBzEpdSqQ2Z9-yAVFxo5UZEgHAPCofDDYn3WAEgU2_VS82XAcE3eNujhLnfnK9Qkg_n9up-xU05Q',
#               'width': 4608}],
#   'place_id': 'ChIJtT9Vy95BIysR2LrYBO6C0Vw',
#   'plus_code': {'compound_code': 'QX6P+W9 Yulara, Northern Territory, '
#                                  'Australia',
#                 'global_code': '5Q6GQX6P+W9'},
#   'rating': 4.7,
#   'reference': 'ChIJtT9Vy95BIysR2LrYBO6C0Vw',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 9,
#   'vicinity': 'Ayers Rock, Yulara Dr, Yulara'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -25.2377193, 'lng': 130.9859995},
#                'viewport': {'northeast': {'lat': -25.23650267010728,
#                                           'lng': 130.9873463798927},
#                             'southwest': {'lat': -25.23920232989272,
#                                           'lng': 130.9846467201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Outback Pioneer - a member of ibis Styles',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/105799077262293827783">A '
#                                     'Google User</a>'],
#               'photo_reference': 'Aap_uECxACKPeWesqoqXbw-cJ7btepMifXOdKVM5XN-dQEEwX799rpXIrefZ-6ONA4qGf031V5ahxCSkkPgDBCIYhwSdTVhWFkrgoGdmMJKUA5VXbRNyokM3mtRSwJd2FwxzurHVSCRAg8EvUoO0NqGiguBShWZ_cKFTRFDdl55mkhUQ3DuK',
#               'width': 4032}],
#   'place_id': 'ChIJXcVyAGxBIysRUP2blWXAF_w',
#   'plus_code': {'compound_code': 'QX6P+W9 Yulara, Northern Territory, '
#                                  'Australia',
#                 'global_code': '5Q6GQX6P+W9'},
#   'rating': 0,
#   'reference': 'ChIJXcVyAGxBIysRUP2blWXAF_w',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 0,
#   'vicinity': 'Ayers Rock, Yulara Dr, Yulara'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -25.2423348, 'lng': 130.9848389},
#                'viewport': {'northeast': {'lat': -25.24099612010728,
#                                           'lng': 130.9862660798927},
#                             'southwest': {'lat': -25.24369577989272,
#                                           'lng': 130.9835664201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Emu Walk Apartments - A member of Grand Mercure Apartments',
#   'opening_hours': {'open_now': True},
#   'place_id': 'ChIJT9TVEzZBIysRMuJ_9Njw_Dw',
#   'plus_code': {'compound_code': 'QX5M+3W Yulara, Northern Territory, '
#                                  'Australia',
#                 'global_code': '5Q6GQX5M+3W'},
#   'rating': 0,
#   'reference': 'ChIJT9TVEzZBIysRMuJ_9Njw_Dw',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 0,
#   'vicinity': 'Ayers Rock, Yulara Dr, Yulara'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -25.2431672, 'lng': 130.9893836},
#                'viewport': {'northeast': {'lat': -25.24181737010727,
#                                           'lng': 130.9907331298927},
#                             'southwest': {'lat': -25.24451702989272,
#                                           'lng': 130.9880334701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Outback Pioneer Lodge - Ayers Rock YHA',
#   'place_id': 'ChIJpTIRhyhAIysR_PhRHds2gro',
#   'plus_code': {'compound_code': 'QX4Q+PQ Yulara, Northern Territory, '
#                                  'Australia',
#                 'global_code': '5Q6GQX4Q+PQ'},
#   'rating': 5,
#   'reference': 'ChIJpTIRhyhAIysR_PhRHds2gro',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1,
#   'vicinity': 'Ayers Rock Resort Ayers Rock, NT 0872 Ayers Rock'}]
# Closest hotel is The Lost Camel Hotel - Ayers Rock Resort.
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 29.03272369999999, 'lng': 21.5458054},
#                'viewport': {'northeast': {'lat': 29.03416212989272,
#                                           'lng': 21.54705467989272},
#                             'southwest': {'lat': 29.03146247010728,
#                                           'lng': 21.54435502010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Jalu Hotel',
#   'photos': [{'height': 549,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/112139596523063101977">hemo '
#                                     'alhdad</a>'],
#               'photo_reference': 'Aap_uEAQFPCnGzrDknbeCrtVuue-JoK18I6ShepSkeMCT3v8DcvFkZwE7TAJJxu8D7ht_AnAm_C6n8cQuMxQJBYv9WJpZW_ltbhTu_eEk23mlAlbuobYUmbPWMBK2tOj2xNJLh4pW2CIC_pP1VH9dvWSvJRrO2fwsuV8JQnICZN-lbJyYhWW',
#               'width': 960}],
#   'place_id': 'ChIJwb2UHcAeiRMRyNRkWbMkgeo',
#   'rating': 3.7,
#   'reference': 'ChIJwb2UHcAeiRMRyNRkWbMkgeo',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 142,
#   'vicinity': '2GMW+38M, Jalu'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 29.0532871, 'lng': 21.5372355},
#                'viewport': {'northeast': {'lat': 29.05477277989273,
#                                           'lng': 21.53836762989272},
#                             'southwest': {'lat': 29.05207312010728,
#                                           'lng': 21.53566797010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'إستراحة صلاح الصادق',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3000,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/100895415731769728179">Ahmad '
#                                     'Almajbry</a>'],
#               'photo_reference': 'Aap_uEAOlSZVcydy434qoEFFzpWYz8mvzfZwVInlqXnioAWZL4iig4iDYB3X1xs9onJgtG_pWMHlFyqUh0fGaVktMJqGOKJHIMlkrEicuF3iP72Fm-fR2shcEHNF-tv8GbJSG-F9OtQTib_138Jm6n0EB6Vu0vThpzTCnjFY-vhLgHd-MjLB',
#               'width': 4000}],
#   'place_id': 'ChIJO-xWCGMfiRMRQ7IZ3IWLNgA',
#   'plus_code': {'compound_code': '3G3P+8V Jalu, Libya',
#                 'global_code': '7GX33G3P+8V'},
#   'rating': 4,
#   'reference': 'ChIJO-xWCGMfiRMRQ7IZ3IWLNgA',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 2,
#   'vicinity': 'Unnamed Road, Jalu'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 29.0398126, 'lng': 21.5353298},
#                'viewport': {'northeast': {'lat': 29.04116697989273,
#                                           'lng': 21.53658027989272},
#                             'southwest': {'lat': 29.03846732010728,
#                                           'lng': 21.53388062010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Thuraya Tourist Hotel',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 405,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/111765613585586198436">طارق '
#                                     'زياد العيش</a>'],
#               'photo_reference': 'Aap_uEBOgIwNFqNY1u2RznYKmamL2D9wD_yjrIzdFLRr_NHXvr4DRZgo5cSIo_LNg3qgeqCRLLHpMcBdybQl6SieOjiIg4Qko7b6ZzRi0NxYh0kth1sJg1FtOLGKA_eliP0AL7I8caG_sW4SH1q8QbobEqsZe8IeJ9hlP9bbdIUPb9_SoSMg',
#               'width': 720}],
#   'place_id': 'ChIJd2o5rOgeiRMR3ALID51m3Ow',
#   'rating': 3.8,
#   'reference': 'ChIJd2o5rOgeiRMR3ALID51m3Ow',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 136,
#   'vicinity': '2GQP+W4G, Jalu'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 29.0321345, 'lng': 21.5456527},
#                'viewport': {'northeast': {'lat': 29.03352222989271,
#                                           'lng': 21.54697637989272},
#                             'southwest': {'lat': 29.03082257010727,
#                                           'lng': 21.54427672010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Ventra Seafood Restaurant',
#   'photos': [{'height': 540,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/107004942661065683286">a '
#                                     'f</a>'],
#               'photo_reference': 'Aap_uEBEORJGFrPL6XkNh8Kh9IVZgyosTMNyAPNHJpSdIv_oqYXtQfJ8C-BDZbePxKhSz14WqL2eD9WoJKsJ8mGvBO1RX7GqOhsv1euW_B8RLj0EMQ9NwID1WSgm134nkhyZw-qK5GFHarKIgsdLQ14gFme9XqdzX5RkSxvgCDFSzk2fbrEu',
#               'width': 960}],
#   'place_id': 'ChIJZ_lYF8AeiRMRTLZFNR92VU8',
#   'rating': 3.9,
#   'reference': 'ChIJZ_lYF8AeiRMRTLZFNR92VU8',
#   'scope': 'GOOGLE',
# ...
#               'width': 4608}],
#   'place_id': 'ChIJ10lAt4xIQBMRKsbUJu_RoyQ',
#   'plus_code': {'compound_code': '34HF+HM Crotone, Province of Crotone, Italy',
#                 'global_code': '8FFV34HF+HM'},
#   'rating': 4.6,
#   'reference': 'ChIJ10lAt4xIQBMRKsbUJu_RoyQ',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 29,
#   'vicinity': 'Corso Giuseppe Mazzini, 31, Crotone'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 39.0712392, 'lng': 17.129295},
#                'viewport': {'northeast': {'lat': 39.07250892989272,
#                                           'lng': 17.13066447989273},
#                             'southwest': {'lat': 39.06980927010728,
#                                           'lng': 17.12796482010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Hotel Tortorelli',
#   'photos': [{'height': 2976,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/104912049441284335403">guido</a>'],
#               'photo_reference': 'Aap_uEApMHjyzHAahHZ33FQ84jh4pnidxlI_YLKyorFsZVWmKJvUL3V6aZq6Z6TJqxmWcHjuSTVKSfqhpsnKR63ItJVv97AWz-esPMY6xTdU3lcz1lYq2axfAVuBD5jccAQautQA-wFikAF-CcHonhbqrra3BueO0EUMfXrylvP0drobDIE0',
#               'width': 3968}],
#   'place_id': 'ChIJI8zxQV9IQBMRuj2eTq2aB6M',
#   'plus_code': {'compound_code': '34CH+FP Crotone, Province of Crotone, Italy',
#                 'global_code': '8FFV34CH+FP'},
#   'rating': 3.7,
#   'reference': 'ChIJI8zxQV9IQBMRuj2eTq2aB6M',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 58,
#   'vicinity': 'Viale Antonio Gramsci, 172, Crotone'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 39.0793522, 'lng': 17.1334552},
#                'viewport': {'northeast': {'lat': 39.08070567989272,
#                                           'lng': 17.13480047989272},
#                             'southwest': {'lat': 39.07800602010727,
#                                           'lng': 17.13210082010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'b&b Donna Raffaela',
#   'place_id': 'ChIJDe2Fq_FIQBMRCwecw2tiJDg',
#   'plus_code': {'compound_code': '34HM+P9 Crotone, Province of Crotone, Italy',
#                 'global_code': '8FFV34HM+P9'},
#   'rating': 4.9,
#   'reference': 'ChIJDe2Fq_FIQBMRCwecw2tiJDg',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 13,
#   'vicinity': 'Via Interna Marina, 107, Crotone'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 39.0539665, 'lng': 17.1366672},
#                'viewport': {'northeast': {'lat': 39.05562872989272,
#                                           'lng': 17.13813507989272},
#                             'southwest': {'lat': 39.05292907010728,
#                                           'lng': 17.13543542010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Bed and Breakfast "Magna Grecia" - Crotone',
#   'photos': [{'height': 1200,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/112790469279668209810">bed '
#                                     'and breakfast magna grecia</a>'],
#               'photo_reference': 'Aap_uEDl4k03iQkSGbSAWu5TvZPqlZ5wO3zMwRHIsmDgDc1d87eKdIfYwFrCpQRrLEa5VynTZNAqyop0PitQIXuKRaNdPn6hgg4vDxzUU1DZ-tY9_4ebmfaSHkr8U7oYSd6kjoN7IeFCMpEDwKFJf5lQaETEEI7yCTYefGCC49xr6x0uck1_',
#               'width': 1600}],
#   'place_id': 'ChIJwxjGoUhIQBMRY4q-65p4DpU',
#   'plus_code': {'compound_code': '343P+HM Crotone, Province of Crotone, Italy',
#                 'global_code': '8FFV343P+HM'},
#   'rating': 4.7,
#   'reference': 'ChIJwxjGoUhIQBMRY4q-65p4DpU',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 79,
#   'vicinity': 'Via Terina, 4, Crotone'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 39.0807732, 'lng': 17.127238},
#                'viewport': {'northeast': {'lat': 39.08212732989272,
#                                           'lng': 17.12859232989273},
#                             'southwest': {'lat': 39.07942767010728,
#                                           'lng': 17.12589267010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'ESTES B&B',
#   'photos': [{'height': 1264,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/115220750770593819724">Mario '
#                                     'V</a>'],
#               'photo_reference': 'Aap_uEDd89X1OHV7otMgSMsoHCtSjA7fkaFcJFTFPlvjNJYtT-wBCzlML6_gGETGNUYqk6R3Dn93112RnyHpH7j2RUdPwrer0yGz4mZFCEHT9_A_lKHMSoW9oj2QbiLGMS7tm-D2uoiUTjM0VhP_XiYGEcHbtsJBTIg81lRjXu912fzOeISg',
#               'width': 1080}],
#   'place_id': 'ChIJ1QHo8PJIQBMREmkwqENV0kg',
#   'plus_code': {'compound_code': '34JG+8V Crotone, Province of Crotone, Italy',
#                 'global_code': '8FFV34JG+8V'},
#   'rating': 4.9,
#   'reference': 'ChIJ1QHo8PJIQBMREmkwqENV0kg',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 14,
#   'vicinity': 'Piazza Pitagora, 30, Crotone'}]
# Closest hotel is Hotel San Giorgio.
# []
# Missing field/result... skipping.
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 41.1537736, 'lng': 80.2586151},
#                'viewport': {'northeast': {'lat': 41.15519387989272,
#                                           'lng': 80.25989527989272},
#                             'southwest': {'lat': 41.15249422010728,
#                                           'lng': 80.25719562010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_pinlet',
#   'name': 'Tianyuan International Hotel',
#   'photos': [{'height': 1960,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/115081063321651143945">Vivian '
#                                     'Tan</a>'],
#               'photo_reference': 'Aap_uEDMmB6uvPwj2DCy2ZMIQ0Saw90oqvqStJyZ02BNZr_uonZwsSEywIWCW8CPCFhGhSbuC1AFzouCCIeyNbAxLNFS-df2ta-vPp5l0aylectFb7edP93fp2yWTWwzAYkmkvz9_Kyfp3iCB8WRpwRHOXePz7mm92_D-ifAm2njfK4HMnUR',
#               'width': 4032}],
#   'place_id': 'ChIJk3kKymbIYzgRtVBaOaQwWPQ',
#   'plus_code': {'compound_code': '5735+GC Yingbazha Residential District, Aksu '
#                                  'City, Aksu Prefecture, Xinjiang, China',
#                 'global_code': '8MH25735+GC'},
#   'rating': 5,
#   'reference': 'ChIJk3kKymbIYzgRtVBaOaQwWPQ',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 3,
#   'vicinity': '阿克苏市滨河路10号'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 41.14176, 'lng': 80.29139599999999},
#                'viewport': {'northeast': {'lat': 41.14320672989273,
#                                           'lng': 80.29268352989271},
#                             'southwest': {'lat': 41.14050707010728,
#                                           'lng': 80.28998387010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Pudong Holiday Hotel',
#   'photos': [{'height': 2592,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/108801437960749872746">Harshad '
#                                     'Parikh</a>'],
#               'photo_reference': 'Aap_uEBgFeAVP0tZhNUB44mNHmsoHR0PvdRzBdoIu58IYBLgaCM3PPR4y00RFSzKwxS9_OIp1IE-xH2HIzR0JAXYiZSGblcllsKWPc4CZ5mnsAj3kt6O-MINXn5NyZQndaS4LCWa3ewkYmr3mLhrIuKUEbIU0ziq2JSwngLCx6_axPFHMVrY',
#               'width': 4608}],
#   'place_id': 'ChIJ2QAxmzDGYzgRE_Eo_Kqhf_8',
#   'plus_code': {'compound_code': '47RR+PH Nancheng Residential District, Aksu '
#                                  'City, Aksu Prefecture, Xinjiang, China',
#                 'global_code': '8MH247RR+PH'},
#   'rating': 5,
#   'reference': 'ChIJ2QAxmzDGYzgRE_Eo_Kqhf_8',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1,
#   'vicinity': 'Aksu Prefecture, Aksu City, Jiaotong Rd, 交通西路1号'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 41.161712, 'lng': 80.28168939999999},
#                'viewport': {'northeast': {'lat': 41.16306597989273,
#                                           'lng': 80.28305822989272},
#                             'southwest': {'lat': 41.16036632010728,
#                                           'lng': 80.28035857010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Jianshe Hotel',
#   'place_id': 'ChIJ85xR7dnHYzgRXm_tqht53g0',
#   'plus_code': {'compound_code': '576J+MM Yiganqixiang, Aksu City, Aksu '
#                                  'Prefecture, Xinjiang, China',
#                 'global_code': '8MH2576J+MM'},
#   'rating': 4.5,
#   'reference': 'ChIJ85xR7dnHYzgRXm_tqht53g0',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 2,
#   'vicinity': 'Aksu City, Tazhong Rd, 塔中路'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 41.167152, 'lng': 80.260522},
#                'viewport': {'northeast': {'lat': 41.16858107989272,
#                                           'lng': 80.26210082989272},
#                             'southwest': {'lat': 41.16588142010728,
#                                           'lng': 80.25940117010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Akesu Yingbin Hotel',
#   'place_id': 'ChIJP6t1mWzIYzgRrHoMU6UbeBM',
#   'plus_code': {'compound_code': '5786+V6 Hongqiao Subdistrict, Aksu, Aksu '
#                                  'City, Aksu Prefecture, Xinjiang, China',
#                 'global_code': '8MH25786+V6'},
#   'rating': 0,
#   'reference': 'ChIJP6t1mWzIYzgRrHoMU6UbeBM',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 0,
#   'vicinity': '1 Xiaonan St, Aksu City, Aksu Prefecture'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 41.169674, 'lng': 80.2636373},
#                'viewport': {'northeast': {'lat': 41.17106307989273,
#                                           'lng': 80.26495817989273},
#                             'southwest': {'lat': 41.16836342010728,
#                                           'lng': 80.26225852010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Songhe Hotel',
#   'place_id': 'ChIJuUaZxRLIYzgR5u6MDO2ZHLE',
#   'plus_code': {'compound_code': '5797+VF Hongqiao Subdistrict, Aksu, Aksu '
#                                  'City, Aksu Prefecture, Xinjiang, China',
#                 'global_code': '8MH25797+VF'},
#   'rating': 0,
#   'reference': 'ChIJuUaZxRLIYzgR5u6MDO2ZHLE',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 0,
#   'vicinity': '4 East St, Aksu City, Aksu Prefecture'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 41.161907, 'lng': 80.28197449999999},
#                'viewport': {'northeast': {'lat': 41.16323957989272,
#                                           'lng': 80.28324737989271},
#                             'southwest': {'lat': 41.16053992010728,
#                                           'lng': 80.28054772010726}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Peacock Hotel',
#   'place_id': 'ChIJyfWli9nHYzgRoS7mokbN-YI',
#   'plus_code': {'compound_code': '576J+QQ Yiganqixiang, Aksu City, Aksu '
#                                  'Prefecture, Xinjiang, China',
#                 'global_code': '8MH2576J+QQ'},
#   'rating': 0,
#   'reference': 'ChIJyfWli9nHYzgRoS7mokbN-YI',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 0,
#   'vicinity': 'Tazhong Rd, Aksu City, Aksu Prefecture'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 41.169864, 'lng': 80.2632},
#                'viewport': {'northeast': {'lat': 41.17113667989272,
#                                           'lng': 80.26460757989271},
#                             'southwest': {'lat': 41.16843702010728,
#                                           'lng': 80.26190792010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Hanting Hotels',
#   'place_id': 'ChIJ6SkX3BLIYzgRb8npc_7PDMc',
#   'plus_code': {'compound_code': '5797+W7 Hongqiao Subdistrict, Aksu, Aksu '
#                                  'City, Aksu Prefecture, Xinjiang, China',
#                 'global_code': '8MH25797+W7'},
#   'rating': 0,
#   'reference': 'ChIJ6SkX3BLIYzgRb8npc_7PDMc',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 0,
#   'vicinity': '1 East St, Akesu Shi, Aksu Prefecture'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 41.169125, 'lng': 80.301926},
#                'viewport': {'northeast': {'lat': 41.17043007989272,
#                                           'lng': 80.30334932989273},
#                             'southwest': {'lat': 41.16773042010728,
#                                           'lng': 80.30064967010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_pinlet',
#   'name': 'Yumei Hotel',
#   'place_id': 'ChIJP0EW_b7HYzgRR6FtOuHC9Hg',
#   'plus_code': {'compound_code': '5892+MQ Nancheng Residential District, Aksu '
#                                  'City, Aksu Prefecture, Xinjiang, China',
#                 'global_code': '8MH25892+MQ'},
#   'rating': 0,
#   'reference': 'ChIJP0EW_b7HYzgRR6FtOuHC9Hg',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 0,
#   'vicinity': '阿克苏市乌喀路108号'}]
# Closest hotel is Tianyuan International Hotel.

# %%
# Visualize to confirm lat lng appear
hotel_df.head()
# Out:
#                 City  City_ID Country  Latitude  Longitude  Temperature  \
# 33             Maham  1264455      IN   28.9833    76.3000       312.92
# 57            Shache  1280037      CN   38.4167    77.2406       305.70
# 100    Bereznehuvate   712339      UA   47.3078    32.8499       305.53
# 125             Asău   686090      RO   46.4333    26.4000       300.66
# 153  Yangi Marg`ilon  1513491      UZ   40.4272    71.7189       303.55
#
#      Humidity  Max Temp  Wind Speed  Cloudiness                  Hotel
# 33         26    312.92        3.69           0   Chobisi Hotel, Meham
# 57         14    305.70        4.88           0   Shache Wanghou Hotel
# 100        30    305.53        2.77           0                  Tulip
# 125        25    305.24        3.00           0       Pensiunea Sophia
# 153        19    303.83        3.09           0  TANTANA HOTEL FERGANA

# %%
# replace empty values with NaN
hotel_df = hotel_df.replace("", np.nan, regex=True)
hotel_df
# Out:
#                    City  City_ID Country  Latitude  Longitude  Temperature  \
# 33                Maham  1264455      IN   28.9833    76.3000       312.92
# 57               Shache  1280037      CN   38.4167    77.2406       305.70
# 100       Bereznehuvate   712339      UA   47.3078    32.8499       305.53
# 125                Asău   686090      RO   46.4333    26.4000       300.66
# 153     Yangi Marg`ilon  1513491      UZ   40.4272    71.7189       303.55
# 191              Yulara  6355222      AU  -25.2406   130.9889       290.06
# 207                Jalu    86049      LY   29.0331    21.5482       306.51
# 220                 Hūn  2216645      LY   29.1268    15.9477       307.74
# 229              Yabrūd   162627      SY   33.9674    36.6574       296.22
# 235             Lugovoy  1521293      KZ   42.9472    72.7644       301.63
# 257        Grootfontein  3357114     NaN  -19.5667    18.1167       298.91
# 286              Waddān  2209055      LY   29.1614    16.1390       307.53
# 302       Alice Springs  2077895      AU  -23.7000   133.8833       286.90
# 317         Miandrivazo  1059051      MG  -19.5167    45.4667       303.72
# 335               Saýat  1218436      TM   38.7839    63.8803       308.08
# 404           Güzelyurt   313199      TR   38.2772    34.3719       297.59
# 446               Opuwo  3354077     NaN  -18.0607    13.8400       301.17
# 468              Riyadh   108410      SA   24.6877    46.7219       315.18
# 484             Senanga   898947      ZM  -16.1167    23.2667       302.20
# 506  Macieira de Cambra  2738052      PT   40.8594    -8.3734       294.85
# 525             Crotone  2524881      IT   39.0851    17.1178       310.12
# 546       Uşak Province   298298      TR   38.5000    29.4167       304.14
# 572                Aksu  1529660      CN   41.1231    80.2644       301.82
#
#      Humidity  Max Temp  Wind Speed  Cloudiness  \
# 33         26    312.92        3.69           0
# 57         14    305.70        4.88           0
# 100        30    305.53        2.77           0
# 125        25    305.24        3.00           0
# 153        19    303.83        3.09           0
# 191        17    290.06        2.57           0
# 207        29    306.51        3.38           0
# 220        18    307.74        1.76           0
# 229        12    296.22        2.20           0
# 235        21    301.63        4.06           0
# 257        22    298.91        3.09           0
# 286        18    307.53        1.15           0
# 302        19    286.90        3.60           0
# 317        24    303.72        1.80           0
# 335         9    308.08        3.31           0
# 404        29    297.59        4.20           0
# 446        17    301.17        3.78           0
# 468         9    315.18        2.06           0
# 484        20    302.20        2.30           0
# 506        30    298.81        0.85           0
# 525        26    310.12        2.57           0
# 546        14    304.14        2.08           0
# 572        15    301.82        2.40           0
#
#                                         Hotel
# 33                       Chobisi Hotel, Meham
# 57                       Shache Wanghou Hotel
# 100                                     Tulip
# 125                          Pensiunea Sophia
# 153                     TANTANA HOTEL FERGANA
# 191  The Lost Camel Hotel - Ayers Rock Resort
# 207                                Jalu Hotel
# 220                             Alrwasi Hotel
# 229                                       NaN
# 235                          Restoran "Alray"
# 257                               Fiume Lodge
# 286                                       NaN
# 302  DoubleTree by Hilton Hotel Alice Springs
# 317                     Princesse Tsiribihina
# 335                                       NaN
# 404                Cappadocia Ihlara Mansions
# 446                       Opuwo Country Lodge
# 468                Radisson Blu Hotel, Riyadh
# 484                             Kashuwa Lodge
# 506                    Hotel Quinta Progresso
# 525                         Hotel San Giorgio
# 546                                       NaN
# 572              Tianyuan International Hotel

# %%
# dropna
narrowed_city_df = hotel_df.dropna()
narrowed_city_df
# Out:
#                    City  City_ID Country  Latitude  Longitude  Temperature  \
# 33                Maham  1264455      IN   28.9833    76.3000       312.92
# 57               Shache  1280037      CN   38.4167    77.2406       305.70
# 100       Bereznehuvate   712339      UA   47.3078    32.8499       305.53
# 125                Asău   686090      RO   46.4333    26.4000       300.66
# 153     Yangi Marg`ilon  1513491      UZ   40.4272    71.7189       303.55
# 191              Yulara  6355222      AU  -25.2406   130.9889       290.06
# 207                Jalu    86049      LY   29.0331    21.5482       306.51
# 220                 Hūn  2216645      LY   29.1268    15.9477       307.74
# 235             Lugovoy  1521293      KZ   42.9472    72.7644       301.63
# 302       Alice Springs  2077895      AU  -23.7000   133.8833       286.90
# 317         Miandrivazo  1059051      MG  -19.5167    45.4667       303.72
# 404           Güzelyurt   313199      TR   38.2772    34.3719       297.59
# 468              Riyadh   108410      SA   24.6877    46.7219       315.18
# 484             Senanga   898947      ZM  -16.1167    23.2667       302.20
# 506  Macieira de Cambra  2738052      PT   40.8594    -8.3734       294.85
# 525             Crotone  2524881      IT   39.0851    17.1178       310.12
# 572                Aksu  1529660      CN   41.1231    80.2644       301.82
#
#      Humidity  Max Temp  Wind Speed  Cloudiness  \
# 33         26    312.92        3.69           0
# 57         14    305.70        4.88           0
# 100        30    305.53        2.77           0
# 125        25    305.24        3.00           0
# 153        19    303.83        3.09           0
# 191        17    290.06        2.57           0
# 207        29    306.51        3.38           0
# 220        18    307.74        1.76           0
# 235        21    301.63        4.06           0
# 302        19    286.90        3.60           0
# 317        24    303.72        1.80           0
# 404        29    297.59        4.20           0
# 468         9    315.18        2.06           0
# 484        20    302.20        2.30           0
# 506        30    298.81        0.85           0
# 525        26    310.12        2.57           0
# 572        15    301.82        2.40           0
#
#                                         Hotel
# 33                       Chobisi Hotel, Meham
# 57                       Shache Wanghou Hotel
# 100                                     Tulip
# 125                          Pensiunea Sophia
# 153                     TANTANA HOTEL FERGANA
# 191  The Lost Camel Hotel - Ayers Rock Resort
# 207                                Jalu Hotel
# 220                             Alrwasi Hotel
# 235                          Restoran "Alray"
# 302  DoubleTree by Hilton Hotel Alice Springs
# 317                     Princesse Tsiribihina
# 404                Cappadocia Ihlara Mansions
# 468                Radisson Blu Hotel, Riyadh
# 484                             Kashuwa Lodge
# 506                    Hotel Quinta Progresso
# 525                         Hotel San Giorgio
# 572              Tianyuan International Hotel

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
locations = narrowed_city_df[["Latitude", "Longitude"]]

# %%
# Add marker layer ontop of heat map

figure_layout = {
    'width': '780px',
    'height': '700px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)
markers = gmaps.marker_layer(locations,
                             info_box_content=hotel_info)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='700px', margin='0 auto 0 auto', padding='1px', wi…

# %%
embed_minimal_html('./002-Output/map_2.html', views=[fig])
